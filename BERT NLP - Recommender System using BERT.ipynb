# %% [markdown]
# <a href="https://colab.research.google.com/github/sahug/ds-bert/blob/main/BERT%20NLP%20-%20Recommender%20System%20using%20BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BERT NLP - Recommender System using BERT**
#
# Gives recommendation based on previous experiance.

# %% [markdown]
# **Load Dataset**

# %%
import zipfile
path_to_zip_file = "/content/US_videos_data.csv.zip"
directory_to_extract_to = "/content/"
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
import pandas as pd
df = pd.read_csv("/content/US_videos_data.csv")

# %%
df = df.drop_duplicates(subset = ['title'])

# %%
df.head()
# Out:
#    Unnamed: 0     video_id                                              title  \
# 0           0  IhO1FcjDMV4  Meatpacking: Last Week Tonight with John Olive...
# 1           1  p4Wy84AOzj0  Best 3D Pen Art Wins $5,000 Challenge! | ZHC C...
# 2           2  4eKXwKDdXYA                   100 Days - [Minecraft Superflat]
# 3           3  XHR5mt2gBjo  Amazing! Luke Bryan Calls 15-Year-Old Casey Bi...
# 4           4  C-icyHEb7W4           Game Theory: Did Reddit Just SOLVE FNAF?
#
#             publishedAt                 channelId        channelTitle  \
# 0  2021-02-22T07:30:01Z  UC3XTzVzaHQEd30rQbuvCtTQ     LastWeekTonight
# 1  2021-02-21T20:43:28Z  UCPAk4rqVIwg1NCXh61VJxbg          ZHC Crafts
# 2  2021-02-20T18:00:01Z  UC9FkeEFIGd9FXRfxpTltXYA     Luke TheNotable
# 3  2021-02-22T01:53:12Z  UCAMPco9PqjBbI_MLsDOO4Jw       American Idol
# 4  2021-02-20T19:05:26Z  UCo_IB5145EVNcf8hw1Kku7w  The Game Theorists
#
#    categoryId trending_date  \
# 0          24      21.22.02
# 1          26      21.22.02
# 2          20      21.22.02
# 3          24      21.22.02
# 4          20      21.22.02
#
#                                                 tags  view_count   likes  \
# 0                                             [none]     1067147   60111
# 1                                             [none]     1047854   50662
# 2  luke thenotable|luke|the|notable|luke thenotab...     6133266  372753
# 3  American Idol|singing competition|Katy Perry|R...      790238   14267
# 4  fnaf|five nights at freddy's|fnaf 4|fnaf theor...     3248661  225780
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      1221           6866  https://i.ytimg.com/vi/IhO1FcjDMV4/default.jpg
# 1       690           4879  https://i.ytimg.com/vi/p4Wy84AOzj0/default.jpg
# 2      7961          39551  https://i.ytimg.com/vi/4eKXwKDdXYA/default.jpg
# 3       129           1257  https://i.ytimg.com/vi/XHR5mt2gBjo/default.jpg
# 4      2872          31885  https://i.ytimg.com/vi/C-icyHEb7W4/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description
# 0  The pandemic has thrown into high relief some ...
# 1  I can't believe we made art using 3d pens and ...
# 2  This video is intended for audiences 13+ years...
# 3  Small but MIGHTY! Casey Bishop completely blow...
# 4  Get Yourself Some BRAND NEW Theory Wear! ► htt...

# %%
ds = df.copy()

# %% [markdown]
# **Data Preperation**

# %%
ds = ds[["title", "description"]]
ds.head()
# Out:
#                                                title  \
# 0  Meatpacking: Last Week Tonight with John Olive...
# 1  Best 3D Pen Art Wins $5,000 Challenge! | ZHC C...
# 2                   100 Days - [Minecraft Superflat]
# 3  Amazing! Luke Bryan Calls 15-Year-Old Casey Bi...
# 4           Game Theory: Did Reddit Just SOLVE FNAF?
#
#                                          description
# 0  The pandemic has thrown into high relief some ...
# 1  I can't believe we made art using 3d pens and ...
# 2  This video is intended for audiences 13+ years...
# 3  Small but MIGHTY! Casey Bishop completely blow...
# 4  Get Yourself Some BRAND NEW Theory Wear! ► htt...

# %% [markdown]
# **Preprocessor and Encoder**

# %%
# %pip install -qq tensorflow_hub
# %pip install -qq tensorflow_text

# %%
import tensorflow_hub as hub
import tensorflow_text as text

# %%
preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1", trainable=True)

# %%
import tensorflow as tf

def get_bert_embeddings(text, preprocessor, encoder):
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
  encoder_inputs = preprocessor(text_input)
  outputs = encoder(encoder_inputs)
  embedding_model = tf.keras.Model(text_input, outputs['pooled_output'])
  sentences = tf.constant([text])
  return embedding_model(sentences)

# %%
ds['encodings'] = ds['title'].apply(lambda x: get_bert_embeddings(x, preprocessor, encoder))

# %%
ds.head()
# Out:
#                                                title  \
# 0  Meatpacking: Last Week Tonight with John Olive...
# 1  Best 3D Pen Art Wins $5,000 Challenge! | ZHC C...
# 2                   100 Days - [Minecraft Superflat]
# 3  Amazing! Luke Bryan Calls 15-Year-Old Casey Bi...
# 4           Game Theory: Did Reddit Just SOLVE FNAF?
#
#                                          description  \
# 0  The pandemic has thrown into high relief some ...
# 1  I can't believe we made art using 3d pens and ...
# 2  This video is intended for audiences 13+ years...
# 3  Small but MIGHTY! Casey Bishop completely blow...
# 4  Get Yourself Some BRAND NEW Theory Wear! ► htt...
#
#                                            encodings
# 0  ((tf.Tensor(-0.99999803, shape=(), dtype=float...
# 1  ((tf.Tensor(-0.9999718, shape=(), dtype=float3...
# 2  ((tf.Tensor(-0.99999654, shape=(), dtype=float...
# 3  ((tf.Tensor(-0.99996674, shape=(), dtype=float...
# 4  ((tf.Tensor(-0.99998075, shape=(), dtype=float...

# %% [markdown]
# **Finding Similarity**

# %%
import re

def preprocess_text(intrest):
  # text = input()
  text = intrest.lower()
  text = re.sub('[^A-Za-z0-9]+', ' ', text)
  return text

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_recommendation(intrest):
  query_text = preprocess_text(intrest)
  query_encoding = get_bert_embeddings(query_text, preprocessor, encoder)
  ds['similarity_score'] = ds['encodings'].apply(lambda x: cosine_similarity(x, query_encoding)[0][0])
  result = ds.sort_values(by=['similarity_score'], ascending=False)
  return result

# %%
get_recommendation("Action, Hollywood, Thrillers")
# Out:
#                                                   title  \
# 1234                       Tom and Jerry - Movie Review
# 1836            Raya and the Last Dragon - Movie Review
# 427                Honest Trailers | The Simpsons Movie
# 4039  Jazmine Sullivan - Pick Up Your Feelings (Offi...
# 150   Sam Fischer, Demi Lovato - What Other People S...
# ...                                                 ...
# 5842  OLYMPIQUE LYONNAIS - PARIS SAINT-GERMAIN (2 - ...
# 5820  Resumen y goles | Costa Rica 0-3 México | Preo...
# 4209  🔴 Live: Grammys 2021 Red Carpet | March 14th, ...
# 4100  2021 F1 Testing | Day 1 Afternoon Session | Ba...
# 1830  [LIVE] ATEEZ 에이티즈 '불놀이야' (I'm The One) Showcas...
#
#                                             description  \
# 1234  Head to http://www.squarespace.com/chrisstuckm...
# 1836  Chris Stuckmann reviews Raya and the Last Drag...
# 427   ►►Subscribe to ScreenJunkies!► https://fandom....
# 4039  “Pick Up Your Feelings” (Official Video) out n...
# 150   Sam Fischer & Demi Lovato – What Other People ...
# ...                                                 ...
# 5842  OLYMPIQUE LYONNAIS vs PARIS SAINT-GERMAIN High...
# 5820  Gustó, goleó y calificó... El Tri dio un treme...
# 4209  Watch interviews with music's biggest stars li...
# 4100  Watch all of F1 2021 Testing Live on F1 TV - h...
# 1830  #ATEEZ #에이티즈​ #불놀이야3월 1일 에이티즈가 여섯 번째 미니앨범 'ZER...
#
#                                               encodings  similarity_score
# 1234  ((tf.Tensor(-0.9999908, shape=(), dtype=float3...          0.978082
# 1836  ((tf.Tensor(-0.99999577, shape=(), dtype=float...          0.974213
# 427   ((tf.Tensor(-0.99999416, shape=(), dtype=float...          0.969347
# 4039  ((tf.Tensor(-0.99999624, shape=(), dtype=float...          0.967798
# 150   ((tf.Tensor(-0.9999976, shape=(), dtype=float3...          0.965828
# ...                                                 ...               ...
# 5842  ((tf.Tensor(-0.99995637, shape=(), dtype=float...          0.725659
# 5820  ((tf.Tensor(-0.99995387, shape=(), dtype=float...          0.724430
# 4209  ((tf.Tensor(-0.9999675, shape=(), dtype=float3...          0.717134
# 4100  ((tf.Tensor(-0.9999534, shape=(), dtype=float3...          0.708580
# 1830  ((tf.Tensor(-0.91622615, shape=(), dtype=float...          0.675271
#
# [1089 rows x 4 columns]

# %%
get_recommendation("Arsenal, Europa league, Premier league")
# Out:
#                                                   title  \
# 59    LIVERPOOL 0-2 EVERTON | PREMIER LEAGUE HIGHLIGHTS
# 5611  Texas vs. Abilene Christian - First Round NCAA...
# 2223  Barcelona’s EPIC comeback! All the action from...
# 5608  Loyola Chicago vs. Illinois - Second Round NCA...
# 135   FC Porto vs. Juventus: Extended Highlights | U...
# ...                                                 ...
# 253               What Your Fortnite Skin Says Of You..
# 2829            i'm moving on... (the full explanation)
# 5642  He Was The Heart & Soul of The Legion Of Boom....
# 5639                  It’s The Fact That Huda Beauty...
# 2422                 This Minecraft Map Read My Mind...
#
#                                             description  \
# 59    Everton recorded a long overdue win at Anfield...
# 5611  The opening round finished with another stunne...
# 2223  Barcelona might win some silverware yet this s...
# 5608  The first one seed fell in the 2021 NCAA Tourn...
# 135   Presented by HeinekenA bittersweet win for Por...
# ...                                                 ...
# 253   What Your Fortnite Skin Says About You.. This ...
# 2829  SIMPLISTIC SATURDAY -   it's a sad day, but i ...
# 5642  Get 20% OFF + Free Shipping @Manscaped with co...
# 5639  Hey guys! Today I’ll be testing the newly refo...
# 2422  sub pls : http://bit.ly/TxtGm8Twitch : http://...
#
#                                               encodings  similarity_score
# 59    ((tf.Tensor(-0.9998858, shape=(), dtype=float3...          0.948221
# 5611  ((tf.Tensor(-0.99992967, shape=(), dtype=float...          0.921210
# 2223  ((tf.Tensor(-0.9993373, shape=(), dtype=float3...          0.918895
# 5608  ((tf.Tensor(-0.99975157, shape=(), dtype=float...          0.913364
# 135   ((tf.Tensor(-0.999879, shape=(), dtype=float32...          0.912981
# ...                                                 ...               ...
# 253   ((tf.Tensor(-0.9999835, shape=(), dtype=float3...          0.540596
# 2829  ((tf.Tensor(-0.99998415, shape=(), dtype=float...          0.537656
# 5642  ((tf.Tensor(-0.99989814, shape=(), dtype=float...          0.533453
# 5639  ((tf.Tensor(-0.99998856, shape=(), dtype=float...          0.532366
# 2422  ((tf.Tensor(-0.9999837, shape=(), dtype=float3...          0.524714
#
# [1089 rows x 4 columns]

# %%
get_recommendation("Music, Taylor Swift, Imagine Dragons")
# Out:
#                                                   title  \
# 2023                  Tate McRae - slower (Lyric Video)
# 4054         Imagine Dragons - Follow You (Lyric Video)
# 4062             Nick Jonas - Spaceman (Official Video)
# 423             DRAGON BALL LEGENDS Video and Stuff #12
# 3606  Maroon 5 - Beautiful Mistakes ft. Megan Thee S...
# ...                                                 ...
# 4214                           What Happened to My Nail
# 5007                                 Where have I been?
# 17                                   i broke my foot...
# 613   How Reddit almost CRASHED the Economy with a m...
# 1830  [LIVE] ATEEZ 에이티즈 '불놀이야' (I'm The One) Showcas...
#
#                                             description  \
# 2023  get slower: https://smarturl.it/slowerxstream ...
# 4054  Listen to Follow You + Cutthroat, out now: htt...
# 4062  Listen to “Spaceman” at https://NickJonas.lnk....
# 423   *Although the video says the new Broly appeare...
# 3606  “Beautiful Mistakes” featuring Megan Thee Stal...
# ...                                                 ...
# 4214  Would have rather broken my jaw than a nail tb...
# 5007                                                NaN
# 17                                           lol oops
# 613   The GameStop short squeeze has probably been o...
# 1830  #ATEEZ #에이티즈​ #불놀이야3월 1일 에이티즈가 여섯 번째 미니앨범 'ZER...
#
#                                               encodings  similarity_score
# 2023  ((tf.Tensor(-0.99998844, shape=(), dtype=float...          0.972059
# 4054  ((tf.Tensor(-0.99998516, shape=(), dtype=float...          0.963154
# 4062  ((tf.Tensor(-0.99999577, shape=(), dtype=float...          0.961594
# 423   ((tf.Tensor(-0.99999416, shape=(), dtype=float...          0.961167
# 3606  ((tf.Tensor(-0.99999565, shape=(), dtype=float...          0.959511
# ...                                                 ...               ...
# 4214  ((tf.Tensor(-0.9999665, shape=(), dtype=float3...          0.730034
# 5007  ((tf.Tensor(-0.99996555, shape=(), dtype=float...          0.729173
# 17    ((tf.Tensor(-0.99987155, shape=(), dtype=float...          0.718878
# 613   ((tf.Tensor(-0.99996406, shape=(), dtype=float...          0.715393
# 1830  ((tf.Tensor(-0.91622615, shape=(), dtype=float...          0.668280
#
# [1089 rows x 4 columns]
